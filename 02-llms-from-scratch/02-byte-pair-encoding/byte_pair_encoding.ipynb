# %% [markdown]
# <a href="https://colab.research.google.com/github/OussamaHaff/machine-learning-upskilling/blob/main/02-llms-from-scratch/02-byte-pair-encoding/byte_pair_encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Byte Pair Encoding

# %%
# !pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2025.1.31)
# Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.9 MB/s eta 0:00:00
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.8.0

# %% [markdown]
# ### Check tiktoken version used by the notebook

# %%
from importlib_metadata import version
import tiktoken

print("tiktoken version:", version("tiktoken"))
# Out:
# tiktoken version: 0.8.0

# %% [markdown]
# ### Encoding using tiktoken BPE

# %%
text = "Hello, do you like tea? <|endoftext|> In the sunlit terraces of someunknownPlace"

tokeniser = tiktoken.get_encoding("gpt2")
ids = tokeniser.encode(text=text, allowed_special={"<|endoftext|>"})
print(ids)
# Out:
# [15496, 11, 466, 345, 588, 8887, 30, 220, 50256, 554, 262, 4252, 18250, 8812, 2114, 286, 617, 34680, 27271]

# %% [markdown]
# ### Decoding using tiktoken BPE

# %%
decoded_text = tokeniser.decode(ids)
print(decoded_text)
# Out:
# Hello, do you like tea? <|endoftext|> In the sunlit terraces of someunknownPlace

# %% [markdown]
# ### Titkton Educational submodules
#
# This helps visualise how the tokeniser construct the byte pairs based on most common occurence of a pair.
#
# Full doc can be found in [openai-cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb).

# %%
from tiktoken._educational import *

enc = train_simple_encoding()

# cl100k_base is the encoding used for gpt-4-turbo, gpt-4, gpt-3.5-turbo,
# text-embedding-ada-002, text-embedding-3-small, text-embedding-3-large
enc = SimpleBytePairEncoding.from_tiktoken("cl100k_base")
enc.encode("hello world aaaaaaaaa")
# Out:
# Streaming output truncated to the last 5000 lines.
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n        ' + b'    '
# So we made b'\n            ' our 326th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' m' + b'erge'
# So we made b' merge' our 327th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'p'
# So we made b' p' our 328th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'is' + b'ual'
# So we made b'isual' our 329th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' token' + b's'
# So we made b' tokens' our 330th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'""' + b'"'
# So we made b'"""' our 331th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'd'
# So we made b' d' our 332th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' v' + b'isual'
# So we made b' visual' our 333th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'in' + b't'
# So we made b'int' our 334th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'co' + b'd'
# So we made b'cod' our 335th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'cod' + b'ing'
# So we made b'coding' our 336th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'str'
# So we made b' str' our 337th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'de' + b'code'
# So we made b'decode' our 338th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n' + b'\n   '
# So we made b'\n\n   ' our 339th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' visual' + b'ise'
# So we made b' visualise' our 340th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'"' + b')'
# So we made b'")' our 341th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' l' + b'i'
# So we made b' li' our 342th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'w' + b'ord'
# So we made b'word' our 343th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'n'
# So we made b' n' our 344th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'+'
# So we made b' +' our 345th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' pa' + b'ir'
# So we made b' pair' our 346th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'se' + b'l'
# So we made b'sel' our 347th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'sel' + b'f'
# So we made b'self' our 348th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'N'
# So we made b' N' our 349th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ou' + b'r'
# So we made b'our' our 350th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'at' + b'a'
# So we made b'ata' our 351th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'm' + b'p'
# So we made b'mp' our 352th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ab' + b'le'
# So we made b'able' our 353th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' in' + b't'
# So we made b' int' our 354th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'on' + b'e'
# So we made b'one' our 355th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'r' + b'n'
# So we made b'rn' our 356th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n' + b'\n       '
# So we made b'\n\n       ' our 357th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' li' + b'st'
# So we made b' list' our 358th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'l' + b'l'
# So we made b'll' our 359th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' word' + b's'
# So we made b' words' our 360th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'r' + b't'
# So we made b'rt' our 361th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'o'
# So we made b' o' our 362th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b't' + b'h'
# So we made b'th' our 363th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' N' + b'one'
# So we made b' None' our 364th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'u'
# So we made b' u' our 365th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' t' + b'o'
# So we made b' to' our 366th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' p' + b'r'
# So we made b' pr' our 367th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'(' + b'"'
# So we made b'("' our 368th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'l' + b'd'
# So we made b'ld' our 369th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'a' + b'c'
# So we made b'ac' our 370th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'token' + b's'
# So we made b'tokens' our 371th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' i' + b'f'
# So we made b' if' our 372th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'col' + b'or'
# So we made b'color' our 373th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'\n            ' + b'   '
# So we made b'\n               ' our 374th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'is'
# So we made b' is' our 375th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'de' + b'f'
# So we made b'def' our 376th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'pa' + b't'
# So we made b'pat' our 377th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ra' + b'in'
# So we made b'rain' our 378th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b's' + b'i'
# So we made b'si' our 379th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'rt' + b's'
# So we made b'rts' our 380th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' pr' + b'int'
# So we made b' print' our 381th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'n' + b'd'
# So we made b'nd' our 382th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b't' + b'u'
# So we made b'tu' our 383th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'-'
# So we made b' -' our 384th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'"""'
# So we made b' """' our 385th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'"'
# So we made b' "' our 386th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' en' + b'c'
# So we made b' enc' our 387th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'll' + b'o'
# So we made b'llo' our 388th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' w' + b'or'
# So we made b' wor' our 389th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' wor' + b'ld'
# So we made b' world' our 390th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'd'
# So we made b'id' our 391th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b"'" + b','
# So we made b"'," our 392th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' d' + b'ata'
# So we made b' data' our 393th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'o' + b'st'
# So we made b'ost' our 394th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'1'
# So we made b' 1' our 395th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'co' + b'm'
# So we made b'com' our 396th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' n' + b'e'
# So we made b' ne' our 397th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'c' + b't'
# So we made b'ct' our 398th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' b' + b'ytes'
# So we made b' bytes' our 399th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'he' + b'llo'
# So we made b'hello' our 400th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' re' + b'tu'
# So we made b' retu' our 401th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' retu' + b'rn'
# So we made b' return' our 402th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'our'
# So we made b' our' our 403th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'com' + b'm'
# So we made b'comm' our 404th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'comm' + b'on'
# So we made b'common' our 405th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ne' + b'w'
# So we made b' new' our 406th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'on'
# So we made b'ion' our 407th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'mp' + b'le'
# So we made b'mple' our 408th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' o' + b'f'
# So we made b' of' our 409th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' pa' + b't'
# So we made b' pat' our 410th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' merge' + b'able'
# So we made b' mergeable' our 411th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' -' + b'>'
# So we made b' ->' our 412th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'p' + b'l'
# So we made b'pl' our 413th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'c'
# So we made b' c' our 414th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' int' + b'o'
# So we made b' into' our 415th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'>' + b'>'
# So we made b'>>' our 416th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' w' + b'e'
# So we made b' we' our 417th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'te' + b'r'
# So we made b'ter' our 418th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'm' + b'e'
# So we made b'me' our 419th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'o' + b'c'
# So we made b'oc' our 420th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'oc' + b'ab'
# So we made b'ocab' our 421th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'si' + b'z'
# So we made b'siz' our 422th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'siz' + b'e'
# So we made b'size' our 423th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' =' + b'='
# So we made b' ==' our 424th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' m' + b'ost'
# So we made b' most' our 425th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'pa' + b'ir'
# So we made b'pair' our 426th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ou' + b'nd'
# So we made b'ound' our 427th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'S'
# So we made b' S' our 428th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'def'
# So we made b' def' our 429th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'u' + b't'
# So we made b'ut' our 430th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'.' + b'_'
# So we made b'._' our 431th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b']' + b':'
# So we made b']:' our 432th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'(' + b'['
# So we made b'([' our 433th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b')' + b':'
# So we made b'):' our 434th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'en' + b'coding'
# So we made b'encoding' our 435th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' pa' + b'rts'
# So we made b' parts' our 436th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'u' + b'e'
# So we made b'ue' our 437th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' m' + b'in'
# So we made b' min' our 438th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'id' + b'x'
# So we made b'idx' our 439th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' l' + b'en'
# So we made b' len' our 440th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'e'
# So we made b' e' our 441th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'en' + b't'
# So we made b'ent' our 442th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'_' + b'_'
# So we made b'__' our 443th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b's' + b's'
# So we made b'ss' our 444th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'E' + b'n'
# So we made b'En' our 445th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' t' + b'h'
# So we made b' th' our 446th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b's'
# So we made b' s' our 447th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'x' + b't'
# So we made b'xt' our 448th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'self'
# So we made b' self' our 449th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'a' + b'p'
# So we made b'ap' our 450th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ap' + b'p'
# So we made b'app' our 451th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'ranks'
# So we made b' ranks' our 452th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'T'
# So we made b' T' our 453th token
# ...
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' l' + b'ast'
# So we made b' last' our 560th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'h' + b'is'
# So we made b'his' our 561th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'at' + b'ion'
# So we made b'ation' our 562th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'm' + b'ent'
# So we made b'ment' our 563th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' b' + b'yte'
# So we made b' byte' our 564th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' en' + b'coding'
# So we made b' encoding' our 565th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'r' + b'o'
# So we made b'ro' our 566th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'mport'
# So we made b'import' our 567th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'k'
# So we made b'ik' our 568th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ik' + b'token'
# So we made b'iktoken' our 569th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' di' + b'ct'
# So we made b' dict' our 570th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'A'
# So we made b' A' our 571th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'te' + b'rn'
# So we made b'tern' our 572th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' u' + b'se'
# So we made b' use' our 573th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' in' + b'p'
# So we made b' inp' our 574th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' inp' + b'ut'
# So we made b' input' our 575th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' t' + b'ext'
# So we made b' text' our 576th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'decode' + b'r'
# So we made b'decoder' our 577th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' en' + b'code'
# So we made b' encode' our 578th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'|'
# So we made b' |' our 579th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'U'
# So we made b' U' our 580th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' [' + b']'
# So we made b' []' our 581th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'decode'
# So we made b' decode' our 582th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'De' + b'codes'
# So we made b'Decodes' our 583th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' re' + b'place'
# So we made b' replace' our 584th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'r' + b'or'
# So we made b'ror' our 585th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'c'
# So we made b'ic' our 586th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' s' + b'o'
# So we made b' so' our 587th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'a' + b'n'
# So we made b'an' our 588th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' wh' + b'ile'
# So we made b' while' our 589th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'me' + b'd'
# So we made b'med' our 590th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ' + b'ou'
# So we made b' ou' our 591th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' ou' + b't'
# So we made b' out' our 592th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' e' + b'l'
# So we made b' el' our 593th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'i' + b'f'
# So we made b'if' our 594th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'si' + b'mple'
# So we made b'simple' our 595th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' al' + b'l'
# So we made b' all' our 596th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b' a' + b'nd'
# So we made b' and' our 597th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'er' + b'e'
# So we made b'ere' our 598th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b']' + b']'
# So we made b']]' our 599th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# The current most common pair is b'ir' + b'st'
# So we made b'irst' our 600th token
# Now the first fifty words in our training data look like:
# """This is an educational implementation of the byte pair encoding algorithm."""
#
# from __future__ import annotations
#
# import collections
#
# import regex
#
# import tiktoken
#
#
# class SimpleBytePairEncoding:
#     def __init__(self, *, pat_str:
#
#
# This is the sequence of merges performed in order to encode 'hello world':
# hello
# hello
# hello
# hello
# hello
#
#  world
#  world
#  world
#  world
#  world
#  world
#
# hello
# hello
# hello
# hello
# hello
#
#  world
#  world
#  world
#  world
#  world
#  world
#
#  aaaaaaaaa
#  aaaaaaaaa
#  aaaaaaaaa
#  aaaaaaaaa
#  aaaaaaaaa
#  aaaaaaaaa
#  aaaaaaaaa
#  aaaaaaaaa
#  aaaaaaaaa
# [15339, 1917, 264, 70540]
